# %% [markdown]
# # Notebook demonstrating quaternion algebra in JAX

# %%
import jax.numpy as jnp
from so3dm.quaternions import q_exp

# %%
q = jnp.array([1,0,0,1])
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
q_exp(q)
# Out:
# DeviceArray([1.4686939, 0.       , 0.       , 2.2873552], dtype=float32)
